# %% [markdown]
# # eks-ray-llm Repo Assistant
#
# **AI-powered co-pilot for your distributed LLM inference platform**
#
# This notebook lets you converse with your entire codebase using xAI Grok Collections + agentic RAG.
#
# - Every file (Terraform, manifests, demos, RAG scripts) is indexed
# - Auto-synced on every commit
# - Grok autonomously retrieves + reasons over your current state
#
# Just write a question → run the cell → get a grounded, proactive answer.

# %%
import sys
import os

# Add rag/ to path so we can import ask_repo
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'rag'))

from ask_repo import ask_repo

print("✅ Repo Assistant loaded — ask anything about your codebase!")

# %% [markdown]
# ### Example Questions (Run one at a time)

# %%
ask_repo("Explain the current EKS node group configuration from infra/ and how it supports the RayCluster in manifests/.")

# %%
ask_repo("Walk me through deploying and testing a vLLM model using serve_demo.py on the current RayCluster.")

# %%
ask_repo("Propose a full plan to add a GPU node group: Terraform changes, taints/tolerations, RayCluster worker updates, and vLLM deployment considerations.")

# %%
ask_repo("If Ray worker pods are pending, what are the most likely causes based on current infra and manifests? Suggest fixes.")

# %% [markdown]
# ### Your Turn — Ask Anything
#
# Write your question below and run the cell:

# %%
# Replace this string with your question
your_question = "Your question here"

print(ask_repo(your_question))
